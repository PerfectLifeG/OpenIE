# %%
import sys
sys.path.append(f"E:\Projects\Python\CCF-NER")  # 保证能找到 src 包
from src.main import main
main(["--config","configs/default.yaml","--split","dev"])
# Out:
# [OK] 抽取完成。路径： outputs\dev_predictions.json
# [OK] 验证完成。路径： outputs\dev_self_verify.json

# %%
# %pip install -U ipywidgets
